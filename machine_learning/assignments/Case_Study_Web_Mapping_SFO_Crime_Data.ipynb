# %%
# STEP 0: Install & import libraries
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\sunil\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\sunil\anaconda3\lib\site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\sunil\anaconda3\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\sunil\anaconda3\lib\site-packages (from folium) (2.1.3)
# Requirement already satisfied: requests in c:\users\sunil\anaconda3\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\sunil\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sunil\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sunil\anaconda3\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sunil\anaconda3\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sunil\anaconda3\lib\site-packages (from requests->folium) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sunil\anaconda3\lib\site-packages (from requests->folium) (2025.10.5)

# %%
import pandas as pd
import folium
from folium.plugins import HeatMap

# %%
# STEP 1: Read the crime dataset
df = pd.read_csv("data/Police_Department_Incidents_Year_2016_.csv")
df.head()
# Out:
#    IncidntNum        Category                                        Descript  \
# 0   120058272     WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272     WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   160075430         ASSAULT         AGGRAVATED ASSAULT WITH A DEADLY WEAPON
# 3   141059263        WARRANTS                                  WARRANT ARREST
# 4   160782306  MISSING PERSON                                    FOUND PERSON
#
#   DayOfWeek                    Date   Time PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00   SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00   SOUTHERN  ARREST, BOOKED
# 2   Tuesday  01/26/2016 12:00:00 AM  19:20  INGLESIDE            NONE
# 3    Monday  04/25/2016 12:00:00 AM  14:59    BAYVIEW  ARREST, BOOKED
# 4    Monday  09/19/2016 12:00:00 AM  05:30       PARK            NONE
#
#                     Address           X          Y  \
# 0    800 Block of BRYANT ST -122.403405  37.775421
# 1    800 Block of BRYANT ST -122.403405  37.775421
# 2  600 Block of ANDERSON ST -122.415432  37.735398
# 3     KEITH ST / SHAFTER AV -122.388856  37.729981
# 4    2000 Block of ELLIS ST -122.439954  37.781359
#
#                                     Location            PdId
# 0     (37.775420706711, -122.40340479147905)  12005827212120
# 1     (37.775420706711, -122.40340479147905)  12005827212168
# 2    (37.73539756503084, -122.4154323065427)  16007543004013
# 3  (37.729980967299596, -122.38885620429184)  14105926363010
# 4   (37.78135894167133, -122.43995406172893)  16078230675000

# %%
#STEP 2: Convert Date column & sort by latest
#(Usually column name = Date)

df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(by='Date', ascending=False)

# %%
# STEP 3: Display first 100 records on a basic map


basic_map = folium.Map(location=[37.77, -122.42], zoom_start=12)

for i, row in df.head(100).iterrows():
    folium.Marker(
        location=[row['Y'], row['X']],
        popup=row['Category']
    ).add_to(basic_map)

basic_map.save("maps/BasicWebMap.html") #Save as BasicWebMap.html

# %%
# MAP 1
# Latest 7 days – ROBBERY crimes

latest_7_days = df[df['Date'] >= df['Date'].max() - pd.Timedelta(days=7)]
robbery_df = latest_7_days[latest_7_days['Category'] == 'ROBBERY']

robbery_map = folium.Map(location=[37.77, -122.42], zoom_start=12)

for i, row in robbery_df.iterrows():
    folium.Marker(
        location=[row['Y'], row['X']],
        popup="ROBBERY",
        icon=folium.Icon(color='red')
    ).add_to(robbery_map)

robbery_map.save("maps/Robbery_Last_7_Days.html")

# %%
#MAP 2
#Latest 15 days – FRAUD & GAMBLING

latest_15_days = df[df['Date'] >= df['Date'].max() - pd.Timedelta(days=15)]
fg_df = latest_15_days[latest_15_days['Category'].isin(['FRAUD', 'GAMBLING'])]

fg_map = folium.Map(location=[37.77, -122.42], zoom_start=12)

for i, row in fg_df.iterrows():
    folium.Marker(
        location=[row['Y'], row['X']],
        popup=row['Category'],
        icon=folium.Icon(icon='info-sign', prefix='fa')
    ).add_to(fg_map)

fg_map.save("maps/Fraud_Gambling_Last_15_Days.html")

# %% [markdown]
# ## Bonus Assignment
# HeatMap – Divvy Bikes (Chicago)

# %%
# step 1) Load bike station data
q3 = pd.read_csv("data/Divvy_Stations_2016_Q3.csv")
q4 = pd.read_csv("data/Divvy_Stations_2016_Q4.csv")

bikes = pd.concat([q3, q4])

# %%
# step 2) Create HeatMap

bike_map = folium.Map(location=[41.88, -87.63], zoom_start=12)

heat_data = [[row['latitude'], row['longitude']] for i, row in bikes.iterrows()]

HeatMap(heat_data).add_to(bike_map)

bike_map.save("maps/Divvy_Bikes_HeatMap.html")

# %%
# Enhancement - 1
# Change map tiles / styles
folium.Map(location=[37.77, -122.42], tiles='Stamen Toner')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f393c90ed817d62f447d3eec8a3c3482 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f393c90ed817d62f447d3eec8a3c3482&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f393c90ed817d62f447d3eec8a3c3482 = L.map(
#                 &quot;map_f393c90ed817d62f447d3eec8a3c3482&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_041d11befa7a2bd16ce97b32cdbe4e1e = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e \u0026mdash; Map data \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_041d11befa7a2bd16ce97b32cdbe4e1e.addTo(map_f393c90ed817d62f447d3eec8a3c3482);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Enhancement 2 - WebMap for BURGLARY – last 7 days
burglary_df = latest_7_days[latest_7_days['Category'] == 'BURGLARY']

# %%
# Enhancement 3 -BONUS - uncomment heatmap code to see changes...
